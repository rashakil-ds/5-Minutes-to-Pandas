# %% [markdown]
# # Module

# %% [markdown]
# 1. Working with NaN
# 2. Handling NaN Values

# %%
import numpy as np
import pandas as pd

# %%
data = np.random.rand(10, 3)
for col in range(data.shape[1]):
    null_indices = np.random.choice(10, 3, replace=False)
    data[null_indices, col] = np.nan
df = pd.DataFrame(data, columns=['Column_1', 'Column_2', 'Column_3'])

# %%
df.head(6)
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000

# %%
#checking with pd.isna()
pd.isna(df['Column_1'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Column_1, dtype: bool

# %%
pd.isna(df)
# Out:
#    Column_1  Column_2  Column_3
# 0     False     False     False
# 1     False     False     False
# 2      True      True     False
# 3     False     False      True
# 4      True     False     False
# 5     False     False     False
# 6      True     False     False
# 7     False     False     False
# 8     False      True      True
# 9     False      True      True

# %%
#checking with pd.notna()
pd.notna(df['Column_1'])
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: Column_1, dtype: bool

# %%
pd.notna(df)
# Out:
#    Column_1  Column_2  Column_3
# 0      True      True      True
# 1      True      True      True
# 2     False     False      True
# 3      True      True     False
# 4     False      True      True
# 5      True      True      True
# 6     False      True      True
# 7      True      True      True
# 8      True     False     False
# 9      True     False     False

# %%
#checking with isnull().sum()
df.isnull()
# Out:
#    Column_1  Column_2  Column_3
# 0     False     False     False
# 1     False     False     False
# 2      True      True     False
# 3     False     False      True
# 4      True     False     False
# 5     False     False     False
# 6      True     False     False
# 7     False     False     False
# 8     False      True      True
# 9     False      True      True

# %%
df.isnull().sum()
# Out:
# Column_1    3
# Column_2    3
# Column_3    3
# dtype: int64

# %%
#checking with notnull().sum()
df.notnull().sum()
# Out:
# Column_1    7
# Column_2    7
# Column_3    7
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column_1  7 non-null      float64
#  1   Column_2  7 non-null      float64
#  2   Column_3  7 non-null      float64
# dtypes: float64(3)
# memory usage: 368.0 bytes

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066       NaN       NaN
# 9  0.252973       NaN       NaN

# %% [markdown]
# # Handling NaN Values

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066       NaN       NaN
# 9  0.252973       NaN       NaN

# %%
df.isnull().sum()
# Out:
# Column_1    3
# Column_2    3
# Column_3    3
# dtype: int64

# %%
df1 = df.copy()

# %%
df1.fillna(0, inplace=True)

# %%
df1.isnull().sum()
# Out:
# Column_1    0
# Column_2    0
# Column_3    0
# dtype: int64

# %%
df1.head()
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2  0.000000  0.000000  0.459462
# 3  0.444163  0.009515  0.000000
# 4  0.000000  0.260931  0.130193

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066       NaN       NaN
# 9  0.252973       NaN       NaN

# %%
df.fillna(
{
    'Column_1': 0,
    'Column_2' : 1,
    'Column_3': 2
})
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2  0.000000  1.000000  0.459462
# 3  0.444163  0.009515  2.000000
# 4  0.000000  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6  0.000000  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066  1.000000  2.000000
# 9  0.252973  1.000000  2.000000

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066       NaN       NaN
# 9  0.252973       NaN       NaN

# %%
df.dropna(how='any')
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 5  0.306231  0.159921  0.502000
# 7  0.028077  0.978706  0.410491

# %%
df.dropna(how='all')
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066       NaN       NaN
# 9  0.252973       NaN       NaN

# %%
df.dropna(thresh=2)
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491

# %%
df.dropna(thresh=3)
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 5  0.306231  0.159921  0.502000
# 7  0.028077  0.978706  0.410491

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [Column_1, Column_2, Column_3]
# Index: []

# %%
df.fillna(
{
    'Column_1': 'aiquest.org',
    'Column_2' : 'study mart',
    'Column_3': 'data science'
})
# Out:
#       Column_1    Column_2      Column_3
# 0      0.84808    0.784691      0.832916
# 1     0.044384     0.83047      0.399888
# 2  aiquest.org  study mart      0.459462
# 3     0.444163    0.009515  data science
# 4  aiquest.org    0.260931      0.130193
# 5     0.306231    0.159921         0.502
# 6  aiquest.org    0.026956      0.771936
# 7     0.028077    0.978706      0.410491
# 8     0.615066  study mart  data science
# 9     0.252973  study mart  data science

# %% [markdown]
# # Filling NaN (missing) values with central tendency

# %%
from IPython.display import Image
Image('ct.png')

# %%
df.fillna(df.mean())
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2  0.362711  0.435884  0.459462
# 3  0.444163  0.009515  0.500984
# 4  0.362711  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6  0.362711  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066  0.435884  0.500984
# 9  0.252973  0.435884  0.500984

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066       NaN       NaN
# 9  0.252973       NaN       NaN

# %%
df.mean()
# Out:
# Column_1    0.362711
# Column_2    0.435884
# Column_3    0.500984
# dtype: float64

# %%
df.fillna(df.median()) # for outlier
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2  0.306231  0.260931  0.459462
# 3  0.444163  0.009515  0.459462
# 4  0.306231  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6  0.306231  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066  0.260931  0.459462
# 9  0.252973  0.260931  0.459462

# %%
df
# Out:
#    Column_1  Column_2  Column_3
# 0  0.848080  0.784691  0.832916
# 1  0.044384  0.830470  0.399888
# 2       NaN       NaN  0.459462
# 3  0.444163  0.009515       NaN
# 4       NaN  0.260931  0.130193
# 5  0.306231  0.159921  0.502000
# 6       NaN  0.026956  0.771936
# 7  0.028077  0.978706  0.410491
# 8  0.615066       NaN       NaN
# 9  0.252973       NaN       NaN

# %%
df.Column_1.mode().iloc[0]
# Out:
# 0.028076718674610368
